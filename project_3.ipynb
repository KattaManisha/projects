# %% [markdown]
# # Rock Paper Scissor Game (Player vs Computer)

# %% [markdown]
# ## Challenge - 1 :

# %% [raw]
# Task-1 : The computer will think of a random choice 'rock or paper or scissor'
# Task-2 : Ask the player to choose 'rock or paper or scissor'
# Task-3 : Compare the player choice with computer,based on the conditions :
#             if player and computer choose the same choice print 'DRAW MATCH'
#             if not print the winner whether it is a player or an computer

# %% [markdown]
# Task-1 : The computer will think of a random choice 'rock or paper or scissor'

# %%
import random

# %%
print(dir(random))
# Out:
# ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_Sequence', '_Set', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_inst', '_log', '_os', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', '_warn', 'betavariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'normalvariate', 'paretovariate', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']

# %%
help("random.Random")
# Out:
# Help on class Random in random:
#
# random.Random = class Random(_random.Random)
#  |  random.Random(x=None)
#  |
#  |  Random number generator base class used by bound module functions.
#  |
#  |  Used to instantiate instances of Random to get generators that don't
#  |  share state.
#  |
#  |  Class Random can also be subclassed if you want to use a different basic
#  |  generator of your own devising: in that case, override the following
#  |  methods:  random(), seed(), getstate(), and setstate().
#  |  Optionally, implement a getrandbits() method so that randrange()
#  |  can cover arbitrarily large ranges.
#  |
#  |  Method resolution order:
#  |      Random
#  |      _random.Random
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getstate__(self)
#  |      # Issue 17489: Since __reduce__ was defined to fix #759889 this is no
#  |      # longer called; we leave it here because it has been here since random was
# ...

# %%
help("random.choice")
# Out:
# Help on method choice in random:
#
# random.choice = choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.

# %%
list1 = ['rock','paper','scissor']
computer_choice = random.choice(list1)

# %% [markdown]
# Task-2 : Ask the player to choose 'rock or paper or scissor'

# %%
player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ")
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper

# %% [markdown]
# Task-3 : Compare the player choice with computer,based on the conditions :
#             if player and computer choose the same choice print 'DRAW MATCH'
#             if not print the winner whether it is a player or an computer

# %%
if player_choice=='rock' and computer_choice=='rock':
    print( 'DRAW MATCH')
    
if player_choice=='rock' and computer_choice=='paper':
    print( 'player loses and computer wins')
    
if player_choice=='rock' and computer_choice=='scissor':
    print( 'player wins and computer loses')
    
if player_choice=='paper' and computer_choice=='rock':
    print( 'player wins and computer loses')
    
if player_choice=='paper' and computer_choice=='paper':
    print( 'DRAW MATCH')
    
if player_choice=='paper' and computer_choice=='scissor':
    print( 'player loses and computer wins')
    
if player_choice=='scissor' and computer_choice=='rock':
    print( 'player loses and computer wins')
    
if player_choice=='scissor' and computer_choice=='paper':
    print( 'player wins and computer loses')
    
if player_choice=='scissor' and computer_choice=='scissor':
    print( 'DRAW MATCH')
# Out:
# DRAW MATCH

# %%
list1 = ['rock','paper','scissor']
computer_choice = random.choice(list1)
player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ")
if player_choice=='rock' and computer_choice=='rock':
    print( 'DRAW MATCH')
    
if player_choice=='rock' and computer_choice=='paper':
    print( 'player loses and computer wins')
    
if player_choice=='rock' and computer_choice=='scissor':
    print( 'player wins and computer loses')
    
if player_choice=='paper' and computer_choice=='rock':
    print( 'player wins and computer loses')
    
if player_choice=='paper' and computer_choice=='paper':
    print( 'DRAW MATCH')
    
if player_choice=='paper' and computer_choice=='scissor':
    print( 'player loses and computer wins')
    
if player_choice=='scissor' and computer_choice=='rock':
    print( 'player loses and computer wins')
    
if player_choice=='scissor' and computer_choice=='paper':
    print( 'player wins and computer loses')
    
if player_choice=='scissor' and computer_choice=='scissor':
    print( 'DRAW MATCH')
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player loses and computer wins

# %% [markdown]
# ## Challenge - 2 :

# %% [raw]
# Task-1 : Print the computer choice and player's choice when loses.
# Task-2 : Let the player play until he is 'BORED' - QUIT the game.
# Task-3 : Optimise the code.

# %% [markdown]
# Task-1 : Print the computer choice and player's choice when loses.

# %%
list1 = ['rock','paper','scissor']
computer_choice = random.choice(list1)
player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ")
if player_choice=='rock' and computer_choice=='rock':
    print( 'DRAW MATCH')
    
if player_choice=='rock' and computer_choice=='paper':
    print( 'player loses and computer wins')
    print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
    
if player_choice=='rock' and computer_choice=='scissor':
    print( 'player wins and computer loses')
    
if player_choice=='paper' and computer_choice=='rock':
    print( 'player wins and computer loses')
    
if player_choice=='paper' and computer_choice=='paper':
    print( 'DRAW MATCH')
    
if player_choice=='paper' and computer_choice=='scissor':
    print( 'player loses and computer wins')
    print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
    
if player_choice=='scissor' and computer_choice=='rock':
    print( 'player loses and computer wins')
    print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
    
if player_choice=='scissor' and computer_choice=='paper':
    print( 'player wins and computer loses')
    
if player_choice=='scissor' and computer_choice=='scissor':
    print( 'DRAW MATCH')
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# DRAW MATCH

# %% [markdown]
# Task-2 : Let the player play until he is 'BORED' - QUIT the game.

# %%
list1 = ['rock','paper','scissor']
while True :    
    computer_choice = random.choice(list1)
    player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ")
    if player_choice=='rock' and computer_choice=='rock':
        print( 'DRAW MATCH')
        print(" ")

    if player_choice=='rock' and computer_choice=='paper':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    if player_choice=='rock' and computer_choice=='scissor':
        print( 'player wins and computer loses')
        print(" ")

    if player_choice=='paper' and computer_choice=='rock':
        print( 'player wins and computer loses')
        print(" ")

    if player_choice=='paper' and computer_choice=='paper':
        print( 'DRAW MATCH')
        print(" ")

    if player_choice=='paper' and computer_choice=='scissor':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    if player_choice=='scissor' and computer_choice=='rock':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    if player_choice=='scissor' and computer_choice=='paper':
        print( 'player wins and computer loses')
        print(" ")

    if player_choice=='scissor' and computer_choice=='scissor':
        print( 'DRAW MATCH')
        print(" ")
        
    if player_choice=='QUIT':
        print("I'M BORED,LET'S PLAY SOME OTHER TIME")
        break
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player loses and computer wins
# The computer choice is :  paper and the player choice : rock
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# DRAW MATCH
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player loses and computer wins
# The computer choice is :  scissor and the player choice : paper
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player loses and computer wins
# The computer choice is :  paper and the player choice : rock
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# DRAW MATCH
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player loses and computer wins
# The computer choice is :  rock and the player choice : scissor
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# DRAW MATCH
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player loses and computer wins
# ...

# %% [markdown]
# Task-3 : Optimise the code.

# %%
list1 = ['rock','paper','scissor']
while True :    
    computer_choice = random.choice(list1)
    player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ")
    if player_choice=='rock' and computer_choice=='rock':
        print( 'DRAW MATCH')
        print(" ")

    elif player_choice=='rock' and computer_choice=='paper':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='rock' and computer_choice=='scissor':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='paper' and computer_choice=='rock':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='paper' and computer_choice=='paper':
        print( 'DRAW MATCH')
        print(" ")

    elif player_choice=='paper' and computer_choice=='scissor':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='scissor' and computer_choice=='rock':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='scissor' and computer_choice=='paper':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='scissor' and computer_choice=='scissor':
        print( 'DRAW MATCH')
        print(" ")
        
    elif player_choice=='QUIT':
        print("I'M BORED,LET'S PLAY SOME OTHER TIME")                
        break
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player loses and computer wins
# The computer choice is :  paper and the player choice : rock
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player loses and computer wins
# The computer choice is :  scissor and the player choice : paper
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# DRAW MATCH
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : QUIT
# I'M BORED,LET'S PLAY SOME OTHER TIME

# %% [markdown]
# ## Challenge - 3 :

# %% [raw]
# Task-1 : Define a function to check who is the winner with a return statement
# Task-2 : Define a function to get computer's input with a return statement
# Task-3 : Define a function to check who is the winner with a return statement

# %% [markdown]
# Task-1 : Define a function to take player's input with a return statement

# %%
list1 = ['rock','paper','scissor']
def take_player_input():
    player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ") 
    return player_choice
while True :    
    computer_choice = random.choice(list1)
    player_choice = take_player_input()
    if player_choice=='rock' and computer_choice=='rock':
        print( 'DRAW MATCH')
        print(" ")

    elif player_choice=='rock' and computer_choice=='paper':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='rock' and computer_choice=='scissor':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='paper' and computer_choice=='rock':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='paper' and computer_choice=='paper':
        print( 'DRAW MATCH')
        print(" ")

    elif player_choice=='paper' and computer_choice=='scissor':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='scissor' and computer_choice=='rock':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='scissor' and computer_choice=='paper':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='scissor' and computer_choice=='scissor':
        print( 'DRAW MATCH')
        print(" ")
        
    elif player_choice=='QUIT':
        print("I'M BORED,LET'S PLAY SOME OTHER TIME")
        break
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player loses and computer wins
# The computer choice is :  paper and the player choice : rock
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# DRAW MATCH
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : QUIT
# I'M BORED,LET'S PLAY SOME OTHER TIME

# %% [markdown]
# Task-2 : Define a function to get computer's input with a return statement

# %%
list1 = ['rock','paper','scissor']
def take_player_input():
    player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ") 
    return player_choice

def get_computer_input():
     return random.choice(list1)
while True :    
    computer_choice = get_computer_input()
    player_choice = take_player_input()
    if player_choice=='rock' and computer_choice=='rock':
        print( 'DRAW MATCH')
        print(" ")

    elif player_choice=='rock' and computer_choice=='paper':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='rock' and computer_choice=='scissor':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='paper' and computer_choice=='rock':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='paper' and computer_choice=='paper':
        print( 'DRAW MATCH')
        print(" ")

    elif player_choice=='paper' and computer_choice=='scissor':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='scissor' and computer_choice=='rock':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")

    elif player_choice=='scissor' and computer_choice=='paper':
        print( 'player wins and computer loses')
        print(" ")

    elif player_choice=='scissor' and computer_choice=='scissor':
        print( 'DRAW MATCH')
        print(" ")
        
    elif player_choice=='QUIT':
        print("I'M BORED,LET'S PLAY SOME OTHER TIME")
        break
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player loses and computer wins
# The computer choice is :  rock and the player choice : scissor
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# DRAW MATCH
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : QUIT
# I'M BORED,LET'S PLAY SOME OTHER TIME

# %% [markdown]
# Task-3 : Define a function to check who is the winner with a return statement

# %%
list1 = ['rock','paper','scissor']
def take_player_input():
    player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ") 
    return player_choice

def get_computer_input():
     return random.choice(list1)
def check_winner(player_choice,computer_choice) :
    if player_choice=='rock' and computer_choice=='rock':
        print( 'DRAW MATCH')
        print(" ")
        return 'tie'

    elif player_choice=='rock' and computer_choice=='paper':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='rock' and computer_choice=='scissor':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='paper' and computer_choice=='rock':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='paper' and computer_choice=='paper':
        print( 'DRAW MATCH')
        print(" ")
        return 'tie'

    elif player_choice=='paper' and computer_choice=='scissor':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='scissor' and computer_choice=='rock':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='scissor' and computer_choice=='paper':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='scissor' and computer_choice=='scissor':
        print( 'DRAW MATCH')
        print(" ") 
        return 'tie'
while True : 
    player_choice = take_player_input()
    computer_choice = get_computer_input()
    if player_choice=='QUIT':
        print("I'M BORED,LET'S PLAY SOME OTHER TIME")
        break
    else:    
        check_winner(player_choice,computer_choice)
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player loses and computer wins
# The computer choice is :  paper and the player choice : rock
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player loses and computer wins
# The computer choice is :  scissor and the player choice : paper
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# DRAW MATCH
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : QUIT
# I'M BORED,LET'S PLAY SOME OTHER TIME

# %% [markdown]
# ## Challenge - 4 :

# %% [raw]
# The game must work normally, when the customer gives input as "QUIT or Quit or quit".

# %%
list1 = ['rock','paper','scissor']
def take_player_input():
    player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ") 
    return player_choice

def get_computer_input():
     return random.choice(list1)

def check_winner(player_choice,computer_choice) :
    if player_choice=='rock' and computer_choice=='rock':
        print( 'DRAW MATCH')
        print(" ")
        return 'tie'

    elif player_choice=='rock' and computer_choice=='paper':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='rock' and computer_choice=='scissor':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='paper' and computer_choice=='rock':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='paper' and computer_choice=='paper':
        print( 'DRAW MATCH')
        print(" ")
        return 'tie'

    elif player_choice=='paper' and computer_choice=='scissor':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='scissor' and computer_choice=='rock':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='scissor' and computer_choice=='paper':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='scissor' and computer_choice=='scissor':
        print( 'DRAW MATCH')
        print(" ") 
        return 'tie'
while True : 
    player_choice = take_player_input()
    computer_choice = get_computer_input()
    if player_choice.upper()=='QUIT':
        print("I'M BORED,LET'S PLAY SOME OTHER TIME")
        break
    else:    
        check_winner(player_choice,computer_choice)
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player loses and computer wins
# The computer choice is :  paper and the player choice : rock
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player loses and computer wins
# The computer choice is :  rock and the player choice : scissor
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player wins and computer loses
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# DRAW MATCH
#
# Enter the choice either 'rock' or 'paper' or 'scissor' : QUIT
# I'M BORED,LET'S PLAY SOME OTHER TIME

# %% [markdown]
# ## Challenge - 5 :

# %% [raw]
# Let's count the computer and player's scores with the help of score board

# %%
list1 = ['rock','paper','scissor']
player_score=0
computer_score=0
def take_player_input():
    player_choice = input("Enter the choice either 'rock' or 'paper' or 'scissor' : ") 
    return player_choice

def get_computer_input():
     return random.choice(list1)

def check_winner(player_choice,computer_choice) :
    if player_choice=='rock' and computer_choice=='rock':
        print( 'DRAW MATCH')
        print(" ")
        return 'tie'

    elif player_choice=='rock' and computer_choice=='paper':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='rock' and computer_choice=='scissor':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='paper' and computer_choice=='rock':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='paper' and computer_choice=='paper':
        print( 'DRAW MATCH')
        print(" ")
        return 'tie'

    elif player_choice=='paper' and computer_choice=='scissor':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='scissor' and computer_choice=='rock':
        print( 'player loses and computer wins')
        print("The computer choice is : ",computer_choice,"and the player choice :",player_choice)
        print(" ")
        return 'computer'

    elif player_choice=='scissor' and computer_choice=='paper':
        print( 'player wins and computer loses')
        print(" ")
        return 'player'

    elif player_choice=='scissor' and computer_choice=='scissor':
        print( 'DRAW MATCH')
        print(" ") 
        return 'tie'
while True : 
    player_choice = take_player_input()
    computer_choice = get_computer_input()

    if player_choice.upper()=='QUIT':
        print("I'M BORED,LET'S PLAY SOME OTHER TIME")
        break
    else:    
        winner=check_winner(player_choice,computer_choice) 
        player = player_choice
        computer = computer_choice
        print("The winner is : ",winner)
        if winner=='player':
            player_score = player_score + 1
        elif winner=='computer':
            computer_score = computer_score + 1
        elif winner=='tie':
            print("No one get's a point ,points shall remain same")
        print("----------score board----------")
        print("player : ",player_score)
        print("computer :",computer_score)
# Out:
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# player loses and computer wins
# The computer choice is :  paper and the player choice : rock
#
# The winner is :  computer
# ----------score board----------
# player :  0
# computer : 1
# Enter the choice either 'rock' or 'paper' or 'scissor' : rock
# DRAW MATCH
#
# The winner is :  tie
# No one get's a point ,points shall remain same
# ----------score board----------
# player :  0
# computer : 1
# Enter the choice either 'rock' or 'paper' or 'scissor' : scissor
# player loses and computer wins
# The computer choice is :  rock and the player choice : scissor
#
# The winner is :  computer
# ----------score board----------
# player :  0
# computer : 2
# Enter the choice either 'rock' or 'paper' or 'scissor' : paper
# player loses and computer wins
# The computer choice is :  scissor and the player choice : paper
#
# The winner is :  computer
# ----------score board----------
# player :  0
# computer : 3
# ...
